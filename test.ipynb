# %%
import numpy as np 
import pandas as pd 
import cv2
import random
from tqdm import tqdm
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
for dirname, _, filenames in os.walk('/home/shashankvenkat/DLP/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv("/home/shashankvenkat/DLP/input/ocular-disease-recognition-odir5k/full_df.csv")
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\Research\DLP\test.ipynb Cell 2 in 1
# ----> <a href='vscode-notebook-cell:/d%3A/Research/DLP/test.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv("/home/shashankvenkat/DLP/input/ocular-disease-recognition-odir5k/full_df.csv")
#       <a href='vscode-notebook-cell:/d%3A/Research/DLP/test.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df.head(3)
#
# File c:\Users\shash\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\shash\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:678, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     663 kwds_defaults = _refine_defaults_read(
#     664     dialect,
#     665     delimiter,
#    (...)
#     674     defaults={"delimiter": ","},
#     675 )
#     676 kwds.update(kwds_defaults)
# --> 678 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\shash\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File c:\Users\shash\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:932, in TextFileReader.__init__(self, f, engine, **kwds)
#     929     self.options["has_index_names"] = kwds["has_index_names"]
#     931 self.handles: IOHandles | None = None
# --> 932 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\shash\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:1216, in TextFileReader._make_engine(self, f, engine)
#    1212     mode = "rb"
#    1213 # error: No overload variant of "get_handle" matches argument types
#    1214 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216 self.handles = get_handle(  # type: ignore[call-overload]
#    1217     f,
#    1218     mode,
#    1219     encoding=self.options.get("encoding", None),
#    1220     compression=self.options.get("compression", None),
#    1221     memory_map=self.options.get("memory_map", False),
#    1222     is_text=is_text,
#    1223     errors=self.options.get("encoding_errors", "strict"),
#    1224     storage_options=self.options.get("storage_options", None),
#    1225 )
#    1226 assert self.handles is not None
#    1227 f = self.handles.handle
#
# File c:\Users\shash\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/shashankvenkat/DLP/input/ocular-disease-recognition-odir5k/full_df.csv'

# %%
def has_cataract(text):
    if "cataract" in text:
        return 1
    else:
        return 0

# %%
df["left_cataract"] = df["Left-Diagnostic Keywords"].apply(lambda x: has_cataract(x))
df["right_cataract"] = df["Right-Diagnostic Keywords"].apply(lambda x: has_cataract(x))

# %%
left_cataract = df.loc[(df.C ==1) & (df.left_cataract == 1)]["Left-Fundus"].values
left_cataract[:15]
# Out:
# array(['0_left.jpg', '81_left.jpg', '103_left.jpg', '119_left.jpg',
#        '254_left.jpg', '294_left.jpg', '330_left.jpg', '448_left.jpg',
#        '465_left.jpg', '477_left.jpg', '553_left.jpg', '560_left.jpg',
#        '594_left.jpg', '611_left.jpg', '625_left.jpg'], dtype=object)

# %%
right_cataract = df.loc[(df.C ==1) & (df.right_cataract == 1)]["Right-Fundus"].values
right_cataract[:15]
# Out:
# array(['24_right.jpg', '81_right.jpg', '112_right.jpg', '188_right.jpg',
#        '218_right.jpg', '345_right.jpg', '354_right.jpg', '477_right.jpg',
#        '553_right.jpg', '560_right.jpg', '625_right.jpg', '726_right.jpg',
#        '769_right.jpg', '949_right.jpg', '955_right.jpg'], dtype=object)

# %%
print("Number of images in left cataract: {}".format(len(left_cataract)))
print("Number of images in right cataract: {}".format(len(right_cataract)))
# Out:
# Number of images in left cataract: 304
# Number of images in right cataract: 290

# %%
left_normal = df.loc[(df.C ==0) & (df["Left-Diagnostic Keywords"] == "normal fundus")]["Left-Fundus"].sample(250,random_state=42).values
right_normal = df.loc[(df.C ==0) & (df["Right-Diagnostic Keywords"] == "normal fundus")]["Right-Fundus"].sample(250,random_state=42).values
right_normal[:15]
# Out:
# array(['2964_right.jpg', '680_right.jpg', '500_right.jpg',
#        '2368_right.jpg', '2820_right.jpg', '2769_right.jpg',
#        '2696_right.jpg', '2890_right.jpg', '940_right.jpg',
#        '2553_right.jpg', '3371_right.jpg', '3042_right.jpg',
#        '919_right.jpg', '3427_right.jpg', '379_right.jpg'], dtype=object)

# %%
cataract = np.concatenate((left_cataract,right_cataract),axis=0)
normal = np.concatenate((left_normal,right_normal),axis=0)

# %%
print(len(cataract),len(normal))
# Out:
# 594 500

# %%
from tensorflow.keras.preprocessing.image import load_img,img_to_array
dataset_dir = "/home/shashankvenkat/DLP/input/ocular-disease-recognition-odir5k/preprocessed_images/"
image_size=224
labels = []
dataset = []
def create_dataset(image_category,label):
    for img in tqdm(image_category):
        image_path = os.path.join(dataset_dir,img)
        try:
            image = cv2.imread(image_path,cv2.IMREAD_COLOR)
            image = cv2.resize(image,(image_size,image_size))
        except:
            continue
        
        dataset.append([np.array(image),np.array(label)])
    random.shuffle(dataset)
    return dataset

# %%
dataset = create_dataset(cataract,1)
# Out:
#   5%|▍         | 28/594 [00:00<00:04, 135.44it/s][ WARN:0@118.347] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/home/shashankvenkat/DLP/input/ocular-disease-recognition-odir5k/preprocessed_images/2102_left.jpg'): can't open/read file: check file path/integrity
#  22%|██▏       | 128/594 [00:00<00:02, 173.73it/s][ WARN:0@118.847] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/home/shashankvenkat/DLP/input/ocular-disease-recognition-odir5k/preprocessed_images/2231_left.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@118.910] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/home/shashankvenkat/DLP/input/ocular-disease-recognition-odir5k/preprocessed_images/2244_left.jpg'): can't open/read file: check file path/integrity
#  25%|██▍       | 146/594 [00:00<00:02, 173.91it/s][ WARN:0@118.930] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/home/shashankvenkat/DLP/input/ocular-disease-recognition-odir5k/preprocessed_images/2251_left.jpg'): can't open/read file: check file path/integrity
#  78%|███████▊  | 465/594 [00:02<00:00, 208.51it/s][ WARN:0@120.544] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/home/shashankvenkat/DLP/input/ocular-disease-recognition-odir5k/preprocessed_images/1456_right.jpg'): can't open/read file: check file path/integrity
#  94%|█████████▍| 559/594 [00:02<00:00, 223.22it/s][ WARN:0@121.012] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/home/shashankvenkat/DLP/input/ocular-disease-recognition-odir5k/preprocessed_images/2229_right.jpg'): can't open/read file: check file path/integrity
# 100%|██████████| 594/594 [00:03<00:00, 196.46it/s]

# %%
len(dataset)
# Out:
# 588

# %%
dataset = create_dataset(normal,0)
# Out:
# 100%|██████████| 500/500 [00:02<00:00, 207.31it/s]

# %%
len(dataset)
# Out:
# 1088

# %%
plt.figure(figsize=(12,7))
for i in range(10):
    sample = random.choice(range(len(dataset)))
    image = dataset[sample][0]
    category = dataset[sample][1]
    if category== 0:
        label = "Normal"
    else:
        label = "Cataract"
    plt.subplot(2,5,i+1)
    plt.imshow(image)
    plt.xlabel(label)
plt.tight_layout()

# %%
x = np.array([i[0] for i in dataset]).reshape(-1,image_size,image_size,3)
y = np.array([i[1] for i in dataset])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from tensorflow.keras.applications.vgg19 import VGG19
vgg = VGG19(weights="imagenet",include_top = False,input_shape=(image_size,image_size,3))
# Out:
# 2022-07-21 18:22:03.042600: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 18:22:03.042943: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib64/python3.10/site-packages/cv2/../../lib64:
# 2022-07-21 18:22:03.043041: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib64/python3.10/site-packages/cv2/../../lib64:
# 2022-07-21 18:22:03.043119: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib64/python3.10/site-packages/cv2/../../lib64:
# 2022-07-21 18:22:03.043192: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib64/python3.10/site-packages/cv2/../../lib64:
# 2022-07-21 18:22:03.043264: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib64/python3.10/site-packages/cv2/../../lib64:
# 2022-07-21 18:22:03.043353: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib64/python3.10/site-packages/cv2/../../lib64:
# 2022-07-21 18:22:03.043427: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib64/python3.10/site-packages/cv2/../../lib64:
# 2022-07-21 18:22:03.043499: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib64/python3.10/site-packages/cv2/../../lib64:
# 2022-07-21 18:22:03.043511: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-07-21 18:22:03.043791: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 116s 1us/step

# %%
for layer in vgg.layers:
    layer.trainable = False

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten,Dense
model = Sequential()
model.add(vgg)
model.add(Flatten())
model.add(Dense(1,activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense (Dense)               (None, 1)                 25089
#
# =================================================================
# Total params: 20,049,473
# Trainable params: 25,089
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
checkpoint = ModelCheckpoint("vgg19.h5",monitor="val_acc",verbose=1,save_best_only=True,
                             save_weights_only=False,period=1)
earlystop = EarlyStopping(monitor="val_acc",patience=5,verbose=1)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(x_train,y_train,batch_size=32,epochs=100,validation_data=(x_test,y_test),
                    verbose=1,callbacks=[checkpoint,earlystop])#32
# Out:
# Epoch 1/100
# 2022-07-21 18:36:11.339232: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 130959360 exceeds 10% of free system memory.
# 2022-07-21 18:36:12.442398: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 19267584 exceeds 10% of free system memory.
# 2022-07-21 18:36:12.448179: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 411041792 exceeds 10% of free system memory.
# 2022-07-21 18:36:12.692874: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 411041792 exceeds 10% of free system memory.
# 2022-07-21 18:36:13.515159: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 102760448 exceeds 10% of free system memory.
# 28/28 [==============================] - ETA: 0s - loss: 1.4405 - accuracy: 0.8851WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 197s 7s/step - loss: 1.4405 - accuracy: 0.8851 - val_loss: 1.6672 - val_accuracy: 0.9083
# Epoch 2/100
# 28/28 [==============================] - ETA: 0s - loss: 0.4074 - accuracy: 0.9701WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 195s 7s/step - loss: 0.4074 - accuracy: 0.9701 - val_loss: 0.5912 - val_accuracy: 0.9404
# Epoch 3/100
# 28/28 [==============================] - ETA: 0s - loss: 0.1006 - accuracy: 0.9839WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 0.1006 - accuracy: 0.9839 - val_loss: 0.5527 - val_accuracy: 0.9541
# Epoch 4/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9908WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 0.0274 - accuracy: 0.9908 - val_loss: 0.2749 - val_accuracy: 0.9633
# Epoch 5/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9977WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 193s 7s/step - loss: 0.0038 - accuracy: 0.9977 - val_loss: 0.4295 - val_accuracy: 0.9633
# Epoch 6/100
# 28/28 [==============================] - ETA: 0s - loss: 4.7536e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 4.7536e-04 - accuracy: 1.0000 - val_loss: 0.4393 - val_accuracy: 0.9725
# Epoch 7/100
# 28/28 [==============================] - ETA: 0s - loss: 2.7539e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 195s 7s/step - loss: 2.7539e-04 - accuracy: 1.0000 - val_loss: 0.4642 - val_accuracy: 0.9725
# Epoch 8/100
# 28/28 [==============================] - ETA: 0s - loss: 9.7872e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 9.7872e-05 - accuracy: 1.0000 - val_loss: 0.4604 - val_accuracy: 0.9725
# Epoch 9/100
# 28/28 [==============================] - ETA: 0s - loss: 8.2944e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 195s 7s/step - loss: 8.2944e-05 - accuracy: 1.0000 - val_loss: 0.4561 - val_accuracy: 0.9725
# Epoch 10/100
# 28/28 [==============================] - ETA: 0s - loss: 7.7857e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 7.7857e-05 - accuracy: 1.0000 - val_loss: 0.4549 - val_accuracy: 0.9725
# Epoch 11/100
# 28/28 [==============================] - ETA: 0s - loss: 6.8957e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 6.8957e-05 - accuracy: 1.0000 - val_loss: 0.4585 - val_accuracy: 0.9725
# Epoch 12/100
# 28/28 [==============================] - ETA: 0s - loss: 6.5728e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 6.5728e-05 - accuracy: 1.0000 - val_loss: 0.4613 - val_accuracy: 0.9725
# Epoch 13/100
# 28/28 [==============================] - ETA: 0s - loss: 6.0862e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 6.0862e-05 - accuracy: 1.0000 - val_loss: 0.4621 - val_accuracy: 0.9725
# Epoch 14/100
# 28/28 [==============================] - ETA: 0s - loss: 5.6310e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 5.6310e-05 - accuracy: 1.0000 - val_loss: 0.4610 - val_accuracy: 0.9725
# Epoch 15/100
# 28/28 [==============================] - ETA: 0s - loss: 5.3365e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 5.3365e-05 - accuracy: 1.0000 - val_loss: 0.4632 - val_accuracy: 0.9725
# Epoch 16/100
# 28/28 [==============================] - ETA: 0s - loss: 5.0074e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 5.0074e-05 - accuracy: 1.0000 - val_loss: 0.4623 - val_accuracy: 0.9725
# Epoch 17/100
# 28/28 [==============================] - ETA: 0s - loss: 4.7909e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 4.7909e-05 - accuracy: 1.0000 - val_loss: 0.4616 - val_accuracy: 0.9725
# Epoch 18/100
# 28/28 [==============================] - ETA: 0s - loss: 4.4987e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 4.4987e-05 - accuracy: 1.0000 - val_loss: 0.4682 - val_accuracy: 0.9725
# Epoch 19/100
# 28/28 [==============================] - ETA: 0s - loss: 4.2577e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 4.2577e-05 - accuracy: 1.0000 - val_loss: 0.4675 - val_accuracy: 0.9725
# Epoch 20/100
# 28/28 [==============================] - ETA: 0s - loss: 4.0465e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 4.0465e-05 - accuracy: 1.0000 - val_loss: 0.4670 - val_accuracy: 0.9725
# Epoch 21/100
# 28/28 [==============================] - ETA: 0s - loss: 3.8378e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 3.8378e-05 - accuracy: 1.0000 - val_loss: 0.4674 - val_accuracy: 0.9725
# Epoch 22/100
# 28/28 [==============================] - ETA: 0s - loss: 3.6848e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 3.6848e-05 - accuracy: 1.0000 - val_loss: 0.4652 - val_accuracy: 0.9725
# Epoch 23/100
# 28/28 [==============================] - ETA: 0s - loss: 3.4830e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 194s 7s/step - loss: 3.4830e-05 - accuracy: 1.0000 - val_loss: 0.4657 - val_accuracy: 0.9725
# Epoch 24/100
# 28/28 [==============================] - ETA: 0s - loss: 3.3686e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 193s 7s/step - loss: 3.3686e-05 - accuracy: 1.0000 - val_loss: 0.4687 - val_accuracy: 0.9679
# Epoch 25/100
# 28/28 [==============================] - ETA: 0s - loss: 3.2734e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 193s 7s/step - loss: 3.2734e-05 - accuracy: 1.0000 - val_loss: 0.4662 - val_accuracy: 0.9679
# Epoch 26/100
# 28/28 [==============================] - ETA: 0s - loss: 3.0731e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 193s 7s/step - loss: 3.0731e-05 - accuracy: 1.0000 - val_loss: 0.4703 - val_accuracy: 0.9679
# Epoch 27/100
# 28/28 [==============================] - ETA: 0s - loss: 2.9653e-05 - accuracy: 1.0000 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 1784s 66s/step - loss: 2.9653e-05 - accuracy: 1.0000 - val_loss: 0.4705 - val_accuracy: 0.9679
# Epoch 28/100
# 28/28 [==============================] - ETA: 0s - loss: 2.8486e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 191s 7s/step - loss: 2.8486e-05 - accuracy: 1.0000 - val_loss: 0.4705 - val_accuracy: 0.9679
# Epoch 29/100
# 28/28 [==============================] - ETA: 0s - loss: 2.7451e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 189s 7s/step - loss: 2.7451e-05 - accuracy: 1.0000 - val_loss: 0.4703 - val_accuracy: 0.9679
# Epoch 30/100
# 28/28 [==============================] - ETA: 0s - loss: 2.6425e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 188s 7s/step - loss: 2.6425e-05 - accuracy: 1.0000 - val_loss: 0.4695 - val_accuracy: 0.9679
# Epoch 31/100
# 28/28 [==============================] - ETA: 0s - loss: 2.5730e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 189s 7s/step - loss: 2.5730e-05 - accuracy: 1.0000 - val_loss: 0.4698 - val_accuracy: 0.9679
# Epoch 32/100
# 28/28 [==============================] - ETA: 0s - loss: 2.4559e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 188s 7s/step - loss: 2.4559e-05 - accuracy: 1.0000 - val_loss: 0.4738 - val_accuracy: 0.9679
# Epoch 33/100
# 28/28 [==============================] - ETA: 0s - loss: 2.4082e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 187s 7s/step - loss: 2.4082e-05 - accuracy: 1.0000 - val_loss: 0.4705 - val_accuracy: 0.9679
# Epoch 34/100
# 28/28 [==============================] - ETA: 0s - loss: 2.3267e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 149s 5s/step - loss: 2.3267e-05 - accuracy: 1.0000 - val_loss: 0.4732 - val_accuracy: 0.9679
# Epoch 35/100
# 28/28 [==============================] - ETA: 0s - loss: 2.2240e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 147s 5s/step - loss: 2.2240e-05 - accuracy: 1.0000 - val_loss: 0.4738 - val_accuracy: 0.9679
# Epoch 36/100
# 28/28 [==============================] - ETA: 0s - loss: 2.1539e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 146s 5s/step - loss: 2.1539e-05 - accuracy: 1.0000 - val_loss: 0.4726 - val_accuracy: 0.9679
# Epoch 37/100
# 28/28 [==============================] - ETA: 0s - loss: 2.0828e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 144s 5s/step - loss: 2.0828e-05 - accuracy: 1.0000 - val_loss: 0.4734 - val_accuracy: 0.9679
# Epoch 38/100
# 28/28 [==============================] - ETA: 0s - loss: 2.0106e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 146s 5s/step - loss: 2.0106e-05 - accuracy: 1.0000 - val_loss: 0.4756 - val_accuracy: 0.9679
# Epoch 39/100
# 28/28 [==============================] - ETA: 0s - loss: 1.9610e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 147s 5s/step - loss: 1.9610e-05 - accuracy: 1.0000 - val_loss: 0.4760 - val_accuracy: 0.9679
# Epoch 40/100
# 28/28 [==============================] - ETA: 0s - loss: 1.9020e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 146s 5s/step - loss: 1.9020e-05 - accuracy: 1.0000 - val_loss: 0.4758 - val_accuracy: 0.9679
# Epoch 41/100
# 28/28 [==============================] - ETA: 0s - loss: 1.8544e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 147s 5s/step - loss: 1.8544e-05 - accuracy: 1.0000 - val_loss: 0.4761 - val_accuracy: 0.9679
# Epoch 42/100
# 28/28 [==============================] - ETA: 0s - loss: 1.7990e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 143s 5s/step - loss: 1.7990e-05 - accuracy: 1.0000 - val_loss: 0.4781 - val_accuracy: 0.9679
# Epoch 43/100
# 28/28 [==============================] - ETA: 0s - loss: 1.7433e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 147s 5s/step - loss: 1.7433e-05 - accuracy: 1.0000 - val_loss: 0.4770 - val_accuracy: 0.9679
# Epoch 44/100
# 28/28 [==============================] - ETA: 0s - loss: 1.6946e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 146s 5s/step - loss: 1.6946e-05 - accuracy: 1.0000 - val_loss: 0.4771 - val_accuracy: 0.9679
# Epoch 45/100
# 28/28 [==============================] - ETA: 0s - loss: 1.6744e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 155s 6s/step - loss: 1.6744e-05 - accuracy: 1.0000 - val_loss: 0.4775 - val_accuracy: 0.9679
# Epoch 46/100
# 28/28 [==============================] - ETA: 0s - loss: 1.6004e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 156s 6s/step - loss: 1.6004e-05 - accuracy: 1.0000 - val_loss: 0.4803 - val_accuracy: 0.9679
# Epoch 47/100
# 28/28 [==============================] - ETA: 0s - loss: 1.5618e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 163s 6s/step - loss: 1.5618e-05 - accuracy: 1.0000 - val_loss: 0.4803 - val_accuracy: 0.9679
# Epoch 48/100
# 28/28 [==============================] - ETA: 0s - loss: 1.5188e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 160s 6s/step - loss: 1.5188e-05 - accuracy: 1.0000 - val_loss: 0.4788 - val_accuracy: 0.9679
# Epoch 49/100
# 28/28 [==============================] - ETA: 0s - loss: 1.4862e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 162s 6s/step - loss: 1.4862e-05 - accuracy: 1.0000 - val_loss: 0.4785 - val_accuracy: 0.9679
# Epoch 50/100
# 28/28 [==============================] - ETA: 0s - loss: 1.4394e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 161s 6s/step - loss: 1.4394e-05 - accuracy: 1.0000 - val_loss: 0.4800 - val_accuracy: 0.9679
# Epoch 51/100
# 28/28 [==============================] - ETA: 0s - loss: 1.4084e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 147s 5s/step - loss: 1.4084e-05 - accuracy: 1.0000 - val_loss: 0.4808 - val_accuracy: 0.9679
# Epoch 52/100
# 28/28 [==============================] - ETA: 0s - loss: 1.3701e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 147s 5s/step - loss: 1.3701e-05 - accuracy: 1.0000 - val_loss: 0.4805 - val_accuracy: 0.9679
# Epoch 53/100
# 28/28 [==============================] - ETA: 0s - loss: 1.3525e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 147s 5s/step - loss: 1.3525e-05 - accuracy: 1.0000 - val_loss: 0.4813 - val_accuracy: 0.9679
# Epoch 54/100
# 28/28 [==============================] - ETA: 0s - loss: 1.3297e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 153s 5s/step - loss: 1.3297e-05 - accuracy: 1.0000 - val_loss: 0.4790 - val_accuracy: 0.9679
# Epoch 55/100
# 28/28 [==============================] - ETA: 0s - loss: 1.2846e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 147s 5s/step - loss: 1.2846e-05 - accuracy: 1.0000 - val_loss: 0.4838 - val_accuracy: 0.9679
# Epoch 56/100
# 28/28 [==============================] - ETA: 0s - loss: 1.2363e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 147s 5s/step - loss: 1.2363e-05 - accuracy: 1.0000 - val_loss: 0.4809 - val_accuracy: 0.9679
# Epoch 57/100
# 28/28 [==============================] - ETA: 0s - loss: 1.2124e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 163s 6s/step - loss: 1.2124e-05 - accuracy: 1.0000 - val_loss: 0.4803 - val_accuracy: 0.9679
# Epoch 58/100
# 28/28 [==============================] - ETA: 0s - loss: 1.1798e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 162s 6s/step - loss: 1.1798e-05 - accuracy: 1.0000 - val_loss: 0.4826 - val_accuracy: 0.9679
# Epoch 59/100
# 28/28 [==============================] - ETA: 0s - loss: 1.1541e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 163s 6s/step - loss: 1.1541e-05 - accuracy: 1.0000 - val_loss: 0.4825 - val_accuracy: 0.9679
# Epoch 60/100
# 28/28 [==============================] - ETA: 0s - loss: 1.1298e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 150s 5s/step - loss: 1.1298e-05 - accuracy: 1.0000 - val_loss: 0.4828 - val_accuracy: 0.9679
# Epoch 61/100
# 28/28 [==============================] - ETA: 0s - loss: 1.0978e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 159s 6s/step - loss: 1.0978e-05 - accuracy: 1.0000 - val_loss: 0.4851 - val_accuracy: 0.9679
# Epoch 62/100
# 28/28 [==============================] - ETA: 0s - loss: 1.0760e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 158s 6s/step - loss: 1.0760e-05 - accuracy: 1.0000 - val_loss: 0.4836 - val_accuracy: 0.9679
# Epoch 63/100
# 28/28 [==============================] - ETA: 0s - loss: 1.0476e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 154s 6s/step - loss: 1.0476e-05 - accuracy: 1.0000 - val_loss: 0.4843 - val_accuracy: 0.9679
# Epoch 64/100
# 28/28 [==============================] - ETA: 0s - loss: 1.0262e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 159s 6s/step - loss: 1.0262e-05 - accuracy: 1.0000 - val_loss: 0.4842 - val_accuracy: 0.9679
# Epoch 65/100
# 28/28 [==============================] - ETA: 0s - loss: 1.0120e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 158s 6s/step - loss: 1.0120e-05 - accuracy: 1.0000 - val_loss: 0.4853 - val_accuracy: 0.9679
# Epoch 66/100
# 28/28 [==============================] - ETA: 0s - loss: 9.9569e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 161s 6s/step - loss: 9.9569e-06 - accuracy: 1.0000 - val_loss: 0.4860 - val_accuracy: 0.9679
# Epoch 67/100
# 28/28 [==============================] - ETA: 0s - loss: 9.8067e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 164s 6s/step - loss: 9.8067e-06 - accuracy: 1.0000 - val_loss: 0.4826 - val_accuracy: 0.9679
# Epoch 68/100
# 28/28 [==============================] - ETA: 0s - loss: 9.4768e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 160s 6s/step - loss: 9.4768e-06 - accuracy: 1.0000 - val_loss: 0.4855 - val_accuracy: 0.9679
# Epoch 69/100
# 28/28 [==============================] - ETA: 0s - loss: 9.2164e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 144s 5s/step - loss: 9.2164e-06 - accuracy: 1.0000 - val_loss: 0.4814 - val_accuracy: 0.9679
# Epoch 70/100
# 28/28 [==============================] - ETA: 0s - loss: 8.9659e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 139s 5s/step - loss: 8.9659e-06 - accuracy: 1.0000 - val_loss: 0.4843 - val_accuracy: 0.9679
# Epoch 71/100
# 28/28 [==============================] - ETA: 0s - loss: 8.7421e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 152s 5s/step - loss: 8.7421e-06 - accuracy: 1.0000 - val_loss: 0.4855 - val_accuracy: 0.9679
# Epoch 72/100
# 28/28 [==============================] - ETA: 0s - loss: 8.6051e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 166s 6s/step - loss: 8.6051e-06 - accuracy: 1.0000 - val_loss: 0.4860 - val_accuracy: 0.9679
# Epoch 73/100
# 28/28 [==============================] - ETA: 0s - loss: 8.4004e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 166s 6s/step - loss: 8.4004e-06 - accuracy: 1.0000 - val_loss: 0.4873 - val_accuracy: 0.9679
# Epoch 74/100
# 28/28 [==============================] - ETA: 0s - loss: 8.2269e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 161s 6s/step - loss: 8.2269e-06 - accuracy: 1.0000 - val_loss: 0.4877 - val_accuracy: 0.9679
# Epoch 75/100
# 28/28 [==============================] - ETA: 0s - loss: 8.0642e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 168s 6s/step - loss: 8.0642e-06 - accuracy: 1.0000 - val_loss: 0.4875 - val_accuracy: 0.9679
# Epoch 76/100
# 28/28 [==============================] - ETA: 0s - loss: 7.9502e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 171s 6s/step - loss: 7.9502e-06 - accuracy: 1.0000 - val_loss: 0.4858 - val_accuracy: 0.9679
# Epoch 77/100
# 28/28 [==============================] - ETA: 0s - loss: 7.7615e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 169s 6s/step - loss: 7.7615e-06 - accuracy: 1.0000 - val_loss: 0.4873 - val_accuracy: 0.9679
# Epoch 78/100
# 28/28 [==============================] - ETA: 0s - loss: 7.6313e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 173s 6s/step - loss: 7.6313e-06 - accuracy: 1.0000 - val_loss: 0.4891 - val_accuracy: 0.9679
# Epoch 79/100
# 28/28 [==============================] - ETA: 0s - loss: 7.4875e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 173s 6s/step - loss: 7.4875e-06 - accuracy: 1.0000 - val_loss: 0.4882 - val_accuracy: 0.9679
# Epoch 80/100
# 28/28 [==============================] - ETA: 0s - loss: 7.3119e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 173s 6s/step - loss: 7.3119e-06 - accuracy: 1.0000 - val_loss: 0.4883 - val_accuracy: 0.9679
# Epoch 81/100
# 28/28 [==============================] - ETA: 0s - loss: 7.1501e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 179s 6s/step - loss: 7.1501e-06 - accuracy: 1.0000 - val_loss: 0.4867 - val_accuracy: 0.9679
# Epoch 82/100
# 28/28 [==============================] - ETA: 0s - loss: 7.0252e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 176s 6s/step - loss: 7.0252e-06 - accuracy: 1.0000 - val_loss: 0.4886 - val_accuracy: 0.9679
# Epoch 83/100
# 28/28 [==============================] - ETA: 0s - loss: 6.8844e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 163s 6s/step - loss: 6.8844e-06 - accuracy: 1.0000 - val_loss: 0.4888 - val_accuracy: 0.9679
# Epoch 84/100
# 28/28 [==============================] - ETA: 0s - loss: 6.7401e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 158s 6s/step - loss: 6.7401e-06 - accuracy: 1.0000 - val_loss: 0.4900 - val_accuracy: 0.9679
# Epoch 85/100
# 28/28 [==============================] - ETA: 0s - loss: 6.6145e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 165s 6s/step - loss: 6.6145e-06 - accuracy: 1.0000 - val_loss: 0.4900 - val_accuracy: 0.9679
# Epoch 86/100
# 28/28 [==============================] - ETA: 0s - loss: 6.5537e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 159s 6s/step - loss: 6.5537e-06 - accuracy: 1.0000 - val_loss: 0.4888 - val_accuracy: 0.9679
# Epoch 87/100
# 28/28 [==============================] - ETA: 0s - loss: 6.4292e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 153s 6s/step - loss: 6.4292e-06 - accuracy: 1.0000 - val_loss: 0.4913 - val_accuracy: 0.9679
# Epoch 88/100
# 28/28 [==============================] - ETA: 0s - loss: 6.2485e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 136s 5s/step - loss: 6.2485e-06 - accuracy: 1.0000 - val_loss: 0.4901 - val_accuracy: 0.9679
# Epoch 89/100
# 28/28 [==============================] - ETA: 0s - loss: 6.1608e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 136s 5s/step - loss: 6.1608e-06 - accuracy: 1.0000 - val_loss: 0.4902 - val_accuracy: 0.9679
# Epoch 90/100
# 28/28 [==============================] - ETA: 0s - loss: 6.0457e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 136s 5s/step - loss: 6.0457e-06 - accuracy: 1.0000 - val_loss: 0.4896 - val_accuracy: 0.9679
# Epoch 91/100
# 28/28 [==============================] - ETA: 0s - loss: 5.9370e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 136s 5s/step - loss: 5.9370e-06 - accuracy: 1.0000 - val_loss: 0.4900 - val_accuracy: 0.9679
# Epoch 92/100
# 28/28 [==============================] - ETA: 0s - loss: 5.8289e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 137s 5s/step - loss: 5.8289e-06 - accuracy: 1.0000 - val_loss: 0.4907 - val_accuracy: 0.9679
# Epoch 93/100
# 28/28 [==============================] - ETA: 0s - loss: 5.7320e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 137s 5s/step - loss: 5.7320e-06 - accuracy: 1.0000 - val_loss: 0.4904 - val_accuracy: 0.9679
# Epoch 94/100
# 28/28 [==============================] - ETA: 0s - loss: 5.6999e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 137s 5s/step - loss: 5.6999e-06 - accuracy: 1.0000 - val_loss: 0.4927 - val_accuracy: 0.9679
# Epoch 95/100
# 28/28 [==============================] - ETA: 0s - loss: 5.5310e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 138s 5s/step - loss: 5.5310e-06 - accuracy: 1.0000 - val_loss: 0.4923 - val_accuracy: 0.9679
# Epoch 96/100
# 28/28 [==============================] - ETA: 0s - loss: 5.4311e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 137s 5s/step - loss: 5.4311e-06 - accuracy: 1.0000 - val_loss: 0.4913 - val_accuracy: 0.9679
# Epoch 97/100
# 28/28 [==============================] - ETA: 0s - loss: 5.3554e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 137s 5s/step - loss: 5.3554e-06 - accuracy: 1.0000 - val_loss: 0.4925 - val_accuracy: 0.9679
# Epoch 98/100
# 28/28 [==============================] - ETA: 0s - loss: 5.2812e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 137s 5s/step - loss: 5.2812e-06 - accuracy: 1.0000 - val_loss: 0.4928 - val_accuracy: 0.9679
# Epoch 99/100
# 28/28 [==============================] - ETA: 0s - loss: 5.2398e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 137s 5s/step - loss: 5.2398e-06 - accuracy: 1.0000 - val_loss: 0.4913 - val_accuracy: 0.9679
# Epoch 100/100
# 28/28 [==============================] - ETA: 0s - loss: 5.1174e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 28/28 [==============================] - 137s 5s/step - loss: 5.1174e-06 - accuracy: 1.0000 - val_loss: 0.4935 - val_accuracy: 0.9679

# %%
loss,accuracy = model.evaluate(x_test,y_test)
print("loss:",loss)
print("Accuracy:",accuracy)
# Out:
# 7/7 [==============================] - 26s 4s/step - loss: 0.4935 - accuracy: 0.9679
# loss: 0.49354109168052673
# Accuracy: 0.9678899049758911

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
yhat_probs = model.predict(x_test, verbose=0)
# predict crisp classes for test set
yhat_classes = np.argmax(model.predict(x_test, verbose=0),axis=1)
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
#yhat_classes = yhat_classes[:, 0]
 
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, yhat_classes)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, yhat_classes)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, yhat_classes)
print('F1 score: %f' % f1)
 
# kappa
kappa = cohen_kappa_score(y_test, yhat_classes)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(y_test, yhat_probs)
print('ROC AUC: %f' % auc)
'''confusion matrix
matrix = confusion_matrix(y_test, yhat_classes)
print(matrix)'''
# Out:
# Accuracy: 0.440367
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/shashankvenkat/DLP/test.ipynb Cell 27 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/home/shashankvenkat/DLP/test.ipynb#ch0000026?line=10'>11</a> print('Accuracy: %f' % accuracy)
#      <a href='vscode-notebook-cell:/home/shashankvenkat/DLP/test.ipynb#ch0000026?line=11'>12</a> # precision tp / (tp + fp)
# ---> <a href='vscode-notebook-cell:/home/shashankvenkat/DLP/test.ipynb#ch0000026?line=12'>13</a> precision = precision_score(y_test, yhat_classes)
#      <a href='vscode-notebook-cell:/home/shashankvenkat/DLP/test.ipynb#ch0000026?line=13'>14</a> print('Precision: %f' % precision)
#      <a href='vscode-notebook-cell:/home/shashankvenkat/DLP/test.ipynb#ch0000026?line=14'>15</a> # recall: tp / (tp + fn)
#
# NameError: name 'precision_score' is not defined

# %%
plt.style.use("ggplot")
fig = plt.figure(figsize=(20,10))
epochs = range(1,101)
plt.subplot(1,2,1)
plt.plot(epochs,history.history["accuracy"],"go-")
plt.plot(epochs,history.history["val_accuracy"],"ro-")
plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train","val"],loc = "upper left")

plt.subplot(1,2,2)
plt.plot(epochs,history.history["loss"],"go-")
plt.plot(epochs,history.history["val_loss"],"ro-")
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train","val"],loc = "upper left")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16412/3385251973.py in <module>
#       4     image = x_test[sample]
#       5     category = y_test[sample]
# ----> 6     pred_category = y_pred[sample]
#       7
#       8     if category== 0:
#
# NameError: name 'y_pred' is not defined
